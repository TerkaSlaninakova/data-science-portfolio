# %%
import pandas as pd
df = pd.read_csv("C:\\workspace\\accuracy_table-complete.csv")

# %%
from IPython.display import display
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
display(df.T)
# Out:
#                                                                   0   \
# Unnamed: 0                          7c81560b1f077f25e0dd594f5bf4ad86
# clf name & configuration    weka.classifiers.bayes.NaiveBayes-['-K']
# AP                                                            0.9615
# MagicTelescope                                                0.9967
# abalone                                                       0.6253
# anneal                                                        0.8608
# ar1                                                           0.8843
# arrhythmia                                                    0.6504
# audiology                                                     0.7168
# autos                                                          0.678
# badges2                                                       0.9932
# balance-scale                                                 0.8336
# baseball                                                      0.8269
# ...

# %%
display(df)
# Out:
#                           Unnamed: 0  \
# 0   7c81560b1f077f25e0dd594f5bf4ad86
# 1   1d516aebeabbf2a07ca7e8ebe18d97c8
# 2   aa8e22e74a528ca8c34f022da26e6b6e
# 3   e4703dbfb0fd5afe7abb4d354a9d37f0
# 4   caf621af10216ec1210297567df473e1
# 5   e4e8820d82a47483a35046e76b9a6e46
# 6   7d713a32ac158c02dd197544f660c29e
# 7   a490a3293e6a1498639fb92fd29bd383
# 8   0eac3706bc1b63d565a61bf3c559133e
# 9   8a17a80704a608727c99c4f5fcb08ef8
# 10  8defbe5a09d5dcdbbc0db8850b0d2723
# 11  55795693f1461bd11c85904f0b24fd44
# 12  79bcd12372c603677cd800fc876f6e87
# 13  11e7bd04a51cebfa54ed0615a1865884
# 14  fa68f3ea0148da945ab04f233b7d86b4
# 15  15a5433c9ff0a01f1f452986b377d916
# 16  6ddac3f39b941be9ae32f919aaa33126
# 17  1168c9bfde0a8c61b18d36d1feaf8f43
# 18  d17dc3dc4024bc64a11e433a5bd34de4
# 19  ce241685d443a617c3abcbf257bf94bf
# 20  a5754099ee06d24899d6c3df39653c5a
# 21  2ec68f22d14b7eb7799d27e39dfb80f4
# 22  3bfe2b3d200317550d951168d116b86c
# 23  eb801df3e0d78e8128692c10c8450bcb
# ...

# %%
display(df.drop(["clf name & configuration", "Unnamed: 0"], axis=1).T.describe(include = 'all').T["mean"].sort_values())
# Out:
# 34    0.611131
# 35    0.623119
# 47    0.631311
# 51    0.632349
# 52    0.633414
# 41    0.647819
# 55    0.733497
# 43    0.758228
# 45    0.778429
# 36    0.779356
# 38    0.779685
# 39    0.783974
# 26    0.785368
# 1     0.789211
# 8     0.789950
# 30    0.791612
# 61    0.792472
# 42    0.793042
# 16    0.795526
# 28    0.800100
# 22    0.800814
# 33    0.802317
# 5     0.803003
# 40    0.803883
# 25    0.806527
# 44    0.806532
# 60    0.806794
# 2     0.809447
# 46    0.811571
# 50    0.812804
#         ...
# 21    0.816474
# 20    0.816474
# 37    0.816939
# 49    0.817839
# 48    0.821361
# 57    0.835690
# 13    0.836340
# 18    0.837333
# 58    0.839286
# 0     0.840289
# 3     0.840755
# 59    0.850218
# 17    0.855272
# 12    0.855542
# 10    0.857632
# 9     0.859849
# 11    0.860604
# 15    0.861097
# 19    0.861247
# 54    0.862056
# 14    0.862190
# 6     0.863352
# 4     0.864308
# 7     0.865083
# 53    0.865126
# 56    0.865376
# 27    0.880458
# 29    0.884462
# ...
